# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
root = Path.cwd().parent
data = root / 'data' / "MO"

# %%
names = pd.read_csv(data / 'names.csv', sep='\t', index_col=0, usecols=[0, 1, 5, 6])
images = pd.read_csv(data / 'images.csv', sep='\t', index_col=0, usecols=[0, 2, 5])
image_o = pd.read_csv(data / 'images_observations.csv', sep='\t', index_col=0)
loc_d = pd.read_csv(data / 'locations.csv', sep='\t', index_col=0,)
name_c = pd.read_csv(data / 'name_classifications.csv', sep='\t', index_col=0)

# %%
observations = pd.read_csv(data / 'observations.csv', sep='\t', index_col=0, parse_dates=[2])

# %%
observations.dropna(subset=['lat', 'long', 'alt'])
# Out:
#         name_id       when  location_id      lat      long     alt  \
# id
# 3824       5067 2007-07-25       1219.0  20.7172 -104.8862  1474.0
# 8530      22581 2012-09-23       4148.0  19.2091  -99.2735  3494.0
# 8742      20662 2008-03-01        326.0 -18.1445  -63.6289   876.0
# 10365       461 2008-08-18       6197.0  20.4008 -104.7013  1436.0
# 10374      5067 2008-08-20       1219.0  20.7172 -104.8862  1474.0
# ...         ...        ...          ...      ...       ...     ...
# 534732    31073 2023-11-04      28660.0  45.7212 -122.5535    87.0
# 534812        1 2023-11-04          NaN  37.9488  -84.8221   207.0
# 534813    20651 2023-09-29       6309.0  37.0000  -77.0000    25.0
# 534814    18700 2019-10-24      28661.0  36.8502  -82.8539   691.0
# 534815      815 2023-10-29      16844.0  45.0000  -71.0000   634.0
#
#         vote_cache  is_collection_location  thumb_image_id
# id
# 3824      2.594850                       1          5702.0
# ...

# %%
loc_d
# Out:
#                                                     name    north    south  \
# id
# 1                 Albion, Mendocino Co., California, USA  39.2408  39.2153
# 2              Burbank, Los Angeles Co., California, USA  34.2217  34.1424
# 3      Mitrula Marsh, Tahoe National Forest, Sierra C...  39.6272  39.6226
# 4      Salt Point State Park, Sonoma Co., California,...  38.5923  38.5584
# 5                Gualala, Mendocino Co., California, USA  38.7868  38.7597
# ...                                                  ...      ...      ...
# 28657  Lake Wahtum, Mount Hood National Forest, Hood ...  45.5862  45.5773
# 28658  Church Creek, Skokomish River, Olympic Nationa...  47.4619  47.4449
# 28659                Rumster Forest, Caithness, Scotland  58.3420  58.3062
# 28660           Vancouver, Clark county, Washington, USA  45.6977  45.5786
# 28661                Lake Keokee, Lee Co., Virginia, USA  36.8548  36.8453
#
#             east      west   high    low
# id
# ...
