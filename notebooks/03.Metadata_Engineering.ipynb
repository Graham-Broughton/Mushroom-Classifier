# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler

# %%
root = Path.cwd().parent
data = root / 'data'

# %%
df = pd.read_csv(data / 'train_val.csv', parse_dates=['date'])

# %%
class_priors = np.zeros(len(df['class_id'].unique()))
for species in df['class_id'].unique():
    class_priors[species] = len(df[df['class_id'] == species])

class_priors = class_priors/sum(class_priors)

month_distributions = {}

for _, observation in tqdm(df.iterrows(), total=len(df)):
    month = str(observation['date'].month)
    class_id = observation.class_id
    if month not in month_distributions:        
        month_distributions[month] = np.zeros(len(df['class_id'].unique()))
    else:
        month_distributions[month][class_id] += 1

for key, value in month_distributions.items():
    month_distributions[key] = value / sum(value)
# Out:
# 100%|██████████| 194743/194743 [00:51<00:00, 3810.82it/s]

# %%
df['norm_date'] = MinMaxScaler().fit_transform(df[['days']])
df.drop('date_c', axis=1).to_csv(data / 'train_val.csv', index=False)

# %%
import pickle

pickle.dump(month_distributions, open(root / 'month_distributions.pkl', 'wb'))
pickle.dump(class_priors, open(root / 'class_priors.pkl', 'wb'))

# %%
df[df['dataset'] == 2018]
# Out:
#                            name             family         phylum  \
# 0     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 1     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 2     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 3     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 4     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# ...                         ...                ...            ...
# 7822       Tremella mesenterica       Tremellaceae  Basidiomycota
# 7823       Tremella mesenterica       Tremellaceae  Basidiomycota
# 7824       Entomophthora muscae  Entomophthoraceae     Zygomycota
# 7825       Entomophthora muscae  Entomophthoraceae     Zygomycota
# 7826       Entomophthora muscae  Entomophthoraceae     Zygomycota
#
#                  order          genus            class  \
# 0          Arthoniales   Herpothallon  Arthoniomycetes
# 1          Arthoniales   Herpothallon  Arthoniomycetes
# 2          Arthoniales   Herpothallon  Arthoniomycetes
# 3          Arthoniales   Herpothallon  Arthoniomycetes
# 4          Arthoniales   Herpothallon  Arthoniomycetes
# ...                ...            ...              ...
# 7822       Tremellales       Tremella  Tremellomycetes
# 7823       Tremellales       Tremella  Tremellomycetes
# 7824  Entomophthorales  Entomophthora      Zygomycetes
# 7825  Entomophthorales  Entomophthora      Zygomycetes
# 7826  Entomophthorales  Entomophthora      Zygomycetes
#
#                                  file_name  height  width  \
# 0     cbb41cb8edf3cfe364e4e3b083ab7a24.jpg     600    800
# 1     755adc87e72ccb246b5b177efb0b8715.jpg     600    800
# 2     0be8000dcc267e8538152788dd4a05fe.jpg     600    800
# 3     e3199adcb85cdf4b66e0066a6957788a.jpg     600    800
# 4     7fc01fe5971cc9d8a5e0ccd49fad91af.jpg     600    800
# ...                                    ...     ...    ...
# 7822  e1321c2693dbcdcd8b56d1526d243711.jpg     800    600
# 7823  4ca620046002ebc2c6da005a178bde05.jpg     800    696
# 7824  6a16cf13d427f97e75553a858fb3343e.jpg     600    800
# 7825  ae3ad120bee653f6642a2c8d8468c975.jpg     800    657
# 7826  2277577d151196c8d5013f63f77bae41.jpg     800    600
#
#       location_uncertainty  ...  date_c   longitude         set  \
# 0                      0.0  ...  0.5852  -81.437020       train
# 1                     29.0  ...  0.8132  -81.436785       train
# 2                      0.0  ...  0.9753  -81.453300       train
# 3                      0.0  ...  0.9753  -81.453300       train
# 4                      0.0  ...  0.5495  -81.210864       train
# ...                    ...  ...     ...         ...         ...
# 7822                3080.0  ...  0.2280  -71.529176  validation
# 7823                2500.0  ...  0.5852  -83.513951  validation
# 7824                   0.0  ...  0.5907 -122.265342  validation
# 7825                   0.0  ...  0.6319 -122.265495  validation
# 7826                   0.0  ...  0.6484 -122.265380  validation
#
#       specific_epithet                                     image_dir_name  \
# 0         rubrocinctum  Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...
# 1         rubrocinctum  Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...
# 2         rubrocinctum  Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...
# 3         rubrocinctum  Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...
# 4         rubrocinctum  Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...
# ...                ...                                                ...
# 7822       mesenterica  Fungi_Basidiomycota_Tremellomycetes_Tremellale...
# 7823       mesenterica  Fungi_Basidiomycota_Tremellomycetes_Tremellale...
# 7824            muscae  Fungi_Zygomycota_Zygomycetes_Entomophthorales_...
# 7825            muscae  Fungi_Zygomycota_Zygomycetes_Entomophthorales_...
# 7826            muscae  Fungi_Zygomycota_Zygomycetes_Entomophthorales_...
#
#      dataset common_name                                          file_path  \
# 0       2018         NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 1       2018         NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 2       2018         NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 3       2018         NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 4       2018         NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# ...      ...         ...                                                ...
# 7822    2018         NaN  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 7823    2018         NaN  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 7824    2018         NaN  Mushroom-Classifier/data/train/Fungi_Zygomycot...
# 7825    2018         NaN  Mushroom-Classifier/data/train/Fungi_Zygomycot...
# 7826    2018         NaN  Mushroom-Classifier/data/train/Fungi_Zygomycot...
#
#                                                gcs_path class_id
# 0     gs://mush-img-repo/train/ Fungi_Ascomycota_Art...      185
# 1     gs://mush-img-repo/train/ Fungi_Ascomycota_Art...      185
# 2     gs://mush-img-repo/train/ Fungi_Ascomycota_Art...      185
# 3     gs://mush-img-repo/train/ Fungi_Ascomycota_Art...      185
# 4     gs://mush-img-repo/train/ Fungi_Ascomycota_Art...      185
# ...                                                 ...      ...
# 7822  gs://mush-img-repo/train/ Fungi_Basidiomycota_...      435
# 7823  gs://mush-img-repo/train/ Fungi_Basidiomycota_...      435
# 7824  gs://mush-img-repo/train/ Fungi_Zygomycota_Zyg...      133
# 7825  gs://mush-img-repo/train/ Fungi_Zygomycota_Zyg...      133
# 7826  gs://mush-img-repo/train/ Fungi_Zygomycota_Zyg...      133
#
# [7827 rows x 22 columns]

# %%
df2 = pd.read_csv(data / '2018_train_val.csv')

# %%
df2[['genus', 'specific_epithet']] = pd.DataFrame(df2['name'].str.split().tolist(), index=df2.index)
df2
# Out:
#                            name             family         phylum  \
# 0     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 1     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 2     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 3     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# 4     Herpothallon rubrocinctum       Arthoniaceae     Ascomycota
# ...                         ...                ...            ...
# 7822       Tremella mesenterica       Tremellaceae  Basidiomycota
# 7823       Tremella mesenterica       Tremellaceae  Basidiomycota
# 7824       Entomophthora muscae  Entomophthoraceae     Zygomycota
# 7825       Entomophthora muscae  Entomophthoraceae     Zygomycota
# 7826       Entomophthora muscae  Entomophthoraceae     Zygomycota
#
#       category_id             order          genus            class  \
# 0            4900       Arthoniales   Herpothallon  Arthoniomycetes
# 1            4900       Arthoniales   Herpothallon  Arthoniomycetes
# 2            4900       Arthoniales   Herpothallon  Arthoniomycetes
# 3            4900       Arthoniales   Herpothallon  Arthoniomycetes
# 4            4900       Arthoniales   Herpothallon  Arthoniomycetes
# ...           ...               ...            ...              ...
# 7822         5219       Tremellales       Tremella  Tremellomycetes
# 7823         5219       Tremellales       Tremella  Tremellomycetes
# 7824         5220  Entomophthorales  Entomophthora      Zygomycetes
# 7825         5220  Entomophthorales  Entomophthora      Zygomycetes
# 7826         5220  Entomophthorales  Entomophthora      Zygomycetes
#
#                                               file_name  height  width  \
# 0     train_val2018/Fungi/4900/cbb41cb8edf3cfe364e4e...     600    800
# 1     train_val2018/Fungi/4900/755adc87e72ccb246b5b1...     600    800
# 2     train_val2018/Fungi/4900/0be8000dcc267e8538152...     600    800
# 3     train_val2018/Fungi/4900/e3199adcb85cdf4b66e00...     600    800
# 4     train_val2018/Fungi/4900/7fc01fe5971cc9d8a5e0c...     600    800
# ...                                                 ...     ...    ...
# 7822  train_val2018/Fungi/5219/e1321c2693dbcdcd8b56d...     800    600
# 7823  train_val2018/Fungi/5219/4ca620046002ebc2c6da0...     800    696
# 7824  train_val2018/Fungi/5220/6a16cf13d427f97e75553...     600    800
# 7825  train_val2018/Fungi/5220/ae3ad120bee653f6642a2...     800    657
# 7826  train_val2018/Fungi/5220/2277577d151196c8d5013...     800    600
#
#       loc_uncert        date        lat  date_c         lon         set  \
# 0              0  2016-08-02  28.367144  0.5852  -81.437020       train
# 1             29  2015-10-24  28.367783  0.8132  -81.436785       train
# 2              0  2016-12-22  28.300703  0.9753  -81.453300       train
# 3              0  2016-12-22  28.300703  0.9753  -81.453300       train
# 4              0  2016-07-20  28.360108  0.5495  -81.210864       train
# ...          ...         ...        ...     ...         ...         ...
# 7822        3080  2012-03-25  42.472635  0.2280  -71.529176  validation
# 7823        2500  2010-08-02  35.676102  0.5852  -83.513951  validation
# 7824           0  2016-08-04  37.803975  0.5907 -122.265342  validation
# 7825           0  2016-08-19  37.803967  0.6319 -122.265495  validation
# 7826           0  2016-08-25  37.803967  0.6484 -122.265380  validation
#
#      specific_epithet
# 0        rubrocinctum
# 1        rubrocinctum
# 2        rubrocinctum
# 3        rubrocinctum
# 4        rubrocinctum
# ...               ...
# 7822      mesenterica
# 7823      mesenterica
# 7824           muscae
# 7825           muscae
# 7826           muscae
#
# [7827 rows x 17 columns]
