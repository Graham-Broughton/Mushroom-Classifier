# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler

# %%
root = Path.cwd().parent
data = root / 'data'

# %%
df = pd.read_csv(data / 'train_val.csv', parse_dates=['date'])

# %%
class_priors = np.zeros(len(df['class_id'].unique()))
for species in df['class_id'].unique():
    class_priors[species] = len(df[df['class_id'] == species])

class_priors = class_priors/sum(class_priors)

month_distributions = {}

for _, observation in tqdm(df.iterrows(), total=len(df)):
    month = str(observation['date'].month)
    class_id = observation.class_id
    if month not in month_distributions:        
        month_distributions[month] = np.zeros(len(df['class_id'].unique()))
    else:
        month_distributions[month][class_id] += 1

for key, value in month_distributions.items():
    month_distributions[key] = value / sum(value)
# Out:
# 100%|██████████| 194743/194743 [00:51<00:00, 3810.82it/s]

# %%
df['norm_date'] = MinMaxScaler().fit_transform(df[['days']])
df.drop('date_c', axis=1).to_csv(data / 'train_val.csv', index=False)

# %%
import pickle

pickle.dump(month_distributions, open(root / 'month_distributions.pkl', 'wb'))
pickle.dump(class_priors, open(root / 'class_priors.pkl', 'wb'))

# %%
df
# Out:
#                              name        family         phylum        order  \
# 0       Herpothallon rubrocinctum  Arthoniaceae     Ascomycota  Arthoniales
# 1       Herpothallon rubrocinctum  Arthoniaceae     Ascomycota  Arthoniales
# 2       Herpothallon rubrocinctum  Arthoniaceae     Ascomycota  Arthoniales
# 3       Herpothallon rubrocinctum  Arthoniaceae     Ascomycota  Arthoniales
# 4       Herpothallon rubrocinctum  Arthoniaceae     Ascomycota  Arthoniales
# ...                           ...           ...            ...          ...
# 194738       Tremella mesenterica  Tremellaceae  Basidiomycota  Tremellales
# 194739       Tremella mesenterica  Tremellaceae  Basidiomycota  Tremellales
# 194740       Tremella mesenterica  Tremellaceae  Basidiomycota  Tremellales
# 194741       Tremella mesenterica  Tremellaceae  Basidiomycota  Tremellales
# 194742       Tremella mesenterica  Tremellaceae  Basidiomycota  Tremellales
#
#                genus            class  \
# 0       Herpothallon  Arthoniomycetes
# 1       Herpothallon  Arthoniomycetes
# 2       Herpothallon  Arthoniomycetes
# 3       Herpothallon  Arthoniomycetes
# 4       Herpothallon  Arthoniomycetes
# ...              ...              ...
# 194738      Tremella  Tremellomycetes
# 194739      Tremella  Tremellomycetes
# 194740      Tremella  Tremellomycetes
# 194741      Tremella  Tremellomycetes
# 194742      Tremella  Tremellomycetes
#
#                                        file_name  height  width  \
# 0           cbb41cb8edf3cfe364e4e3b083ab7a24.jpg     600    800
# 1           755adc87e72ccb246b5b177efb0b8715.jpg     600    800
# 2           0be8000dcc267e8538152788dd4a05fe.jpg     600    800
# 3           e3199adcb85cdf4b66e0066a6957788a.jpg     600    800
# 4           7fc01fe5971cc9d8a5e0ccd49fad91af.jpg     600    800
# ...                                          ...     ...    ...
# 194738  51f13b0b-f4f7-46ed-9e53-4d0c63ddad6b.jpg     375    500
# 194739  294cf8dc-bfaa-45b7-a7a8-205d1a22e33d.jpg     375    500
# 194740  b3b8cb90-d5d6-4118-826f-d69c6803a11a.jpg     341    500
# 194741  f38f1edd-34f2-4e8d-aaeb-c95ed22dd1ca.jpg     500    410
# 194742  f8aa8d5e-6dab-4a50-9fc1-8a893d3740c6.jpg     349    500
#
#         location_uncertainty  ...  \
# 0                        0.0  ...
# 1                       29.0  ...
# 2                        0.0  ...
# 3                        0.0  ...
# 4                        0.0  ...
# ...                      ...  ...
# 194738                  13.0  ...
# 194739                  44.0  ...
# 194740                 197.0  ...
# 194741                  15.0  ...
# 194742                 221.0  ...
#
#                                            image_dir_name  dataset  \
# 0       Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...     2018
# 1       Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...     2018
# 2       Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...     2018
# 3       Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...     2018
# 4       Fungi_Ascomycota_Arthoniomycetes_Arthoniales_A...     2018
# ...                                                   ...      ...
# 194738  Fungi_Basidiomycota_Tremellomycetes_Tremellale...     2021
# 194739  Fungi_Basidiomycota_Tremellomycetes_Tremellale...     2021
# 194740  Fungi_Basidiomycota_Tremellomycetes_Tremellale...     2021
# 194741  Fungi_Basidiomycota_Tremellomycetes_Tremellale...     2021
# 194742  Fungi_Basidiomycota_Tremellomycetes_Tremellale...     2021
#
#            common_name                                          file_path  \
# 0                  NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 1                  NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 2                  NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 3                  NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# 4                  NaN  Mushroom-Classifier/data/train/Fungi_Ascomycot...
# ...                ...                                                ...
# 194738  witch's butter  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 194739  witch's butter  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 194740  witch's butter  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 194741  witch's butter  Mushroom-Classifier/data/train/Fungi_Basidiomy...
# 194742  witch's butter  Mushroom-Classifier/data/train/Fungi_Basidiomy...
#
#                                                  gcs_path month  class_id  \
# 0       gs://mush-img-repo/train/ Fungi_Ascomycota_Art...     8       185
# 1       gs://mush-img-repo/train/ Fungi_Ascomycota_Art...    10       185
# 2       gs://mush-img-repo/train/ Fungi_Ascomycota_Art...    12       185
# 3       gs://mush-img-repo/train/ Fungi_Ascomycota_Art...    12       185
# 4       gs://mush-img-repo/train/ Fungi_Ascomycota_Art...     7       185
# ...                                                   ...   ...       ...
# 194738  gs://mush-img-repo/train/ Fungi_Basidiomycota_...     5       435
# 194739  gs://mush-img-repo/train/ Fungi_Basidiomycota_...     6       435
# 194740  gs://mush-img-repo/train/ Fungi_Basidiomycota_...     6       435
# 194741  gs://mush-img-repo/train/ Fungi_Basidiomycota_...    10       435
# 194742  gs://mush-img-repo/train/ Fungi_Basidiomycota_...     6       435
#
#         year days norm_date
# 0       2016  215  0.586301
# 1       2015  297  0.810959
# 2       2016  357  0.975342
# 3       2016  357  0.975342
# 4       2016  202  0.550685
# ...      ...  ...       ...
# 194738  2019  131  0.356164
# 194739  2019  160  0.435616
# 194740  2019  167  0.454795
# 194741  2018  282  0.769863
# 194742  2013  165  0.449315
#
# [194743 rows x 25 columns]
