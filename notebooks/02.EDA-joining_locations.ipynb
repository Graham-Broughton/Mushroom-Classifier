# %%
import pandas as pd
import json
from pathlib import Path
from IPython.display import display

# %%
root = Path.cwd().parent
data = root / 'data' / 'raw'

# %%
def parse_json(filepath, istest=False, categories=None):
    with open(filepath, 'r') as f:
        res = json.load(f)
    info = pd.DataFrame.from_dict(res['info'], orient='index')
    images = pd.DataFrame(res['images']).set_index('id')
    if not istest:
        annotations = pd.DataFrame(res['annotations']).set_index('id')
        if categories:
            categories = pd.DataFrame(res['categories']).set_index('id')
            return info, images, annotations, categories
        return info, images, annotations

    return info, images

def join_dataframes(images, annotations, categories, locations=None):
    categories = categories[categories['supercategory'] == 'Fungi']
    categories = categories.rename(columns={'id': 'category_id'})
    if locations is None:
        df = categories.merge(annotations, right_on='category_id', left_index=True, how='inner').merge(images, left_on='image_id', right_index=True, how='inner')
    else:
        df = categories.merge(annotations, right_on='category_id', left_index=True, how='inner').merge(images, left_on='image_id', right_index=True, how='inner').merge(locations, left_on='image_id', right_index=True, how='inner')
    try:
        df = df.drop(['supercategory', 'kingdom', 'image_id', 'valid', 'license', 'rights_holder', 'user_id'], axis=1)
    except KeyError:
        df = df.drop(['supercategory', 'kingdom', 'image_id', 'license', 'rights_holder'], axis=1)
    finally:
        return df

# %% [markdown]
# ## Parse JSON Data

# %%
tinfo2018, timages2018, tanno2018 = parse_json(data / '2018' / 'train2018.json')
vinfo2018, vimages2018, vanno2018 = parse_json(data / '2018' / 'val2018.json')
testinfo2018, testimages2018 = parse_json(data / '2018' / 'test2018.json', istest=True)
tloc = pd.read_json(data / '2018' / 'inat2018_locations' / 'train2018_locations.json').set_index('id')
vloc = pd.read_json(data / '2018' / 'inat2018_locations' / 'val2018_locations.json').set_index('id')

with open(data / '2018' / 'categories.json', 'r') as f:
    res = json.load(f)
    cats = pd.DataFrame(res)

tinfo2019, timages2019, tanno2019, tcat2019 = parse_json(data / '2019' / 'train2019.json', categories=True)

tinfo2021, timages2021, tanno2021, tcat2021 = parse_json(data / '2021' / 'train.json', categories=True)
vinfo2021, vimages2021, vanno2021, vcat2021 = parse_json(data / '2021' / 'val.json', categories=True)
testinfo2021, testimages2021 = parse_json(data / '2021' / 'public_test.json', istest=True)

# %% [markdown]
# # 2018 Dataset

# %%
display(tloc)
display(timages2018)
display(tanno2018)
display(cats)
# Out:
#         loc_uncert       date  valid  user_id        lat  date_c         lon
# id
# 1                0 2016-05-20   True    15723  38.913837  0.3819  -76.942313
# 2               42 2015-01-16   True    42760  50.578740  0.0412    6.374398
# 3               12 2016-09-08   True   121416  49.269860  0.6868 -123.260819
# 4              500 2011-02-05   True    16823  35.131031  0.0962 -106.682600
# 5              173 2015-05-15   True    40730  19.503475  0.3681  -99.142810
# ...            ...        ...    ...      ...        ...     ...         ...
# 437509          91 2016-06-01   True   178946  46.232355  0.4148 -123.398609
# 437510           4 2015-07-13   True    22589  32.559797  0.5302  -97.108282
# 437511         124 2016-02-14   True    54888  20.870175  0.1209  -87.087176
# 437512           0 2013-06-10   True    11792  39.599833  0.4396  -82.630000
# 437513           0 2013-09-08   True     5692  38.927000  0.6868 -121.040000
#
# [437513 rows x 7 columns]
#         license                                          file_name  \
# id
# 1             3  train_val2018/Plantae/7477/3b60c9486db1d2ee875...
# 2             3  train_val2018/Aves/2820/22c733d9199c35d2578232...
# 3             3  train_val2018/Aves/2757/e5641ce8fd794bf149d49f...
# 4             1  train_val2018/Mammalia/4219/60c8365f55c2f4e790...
# 5             3  train_val2018/Aves/3942/872fef47a85beb90efc301...
# ...         ...                                                ...
# 437509        3  train_val2018/Plantae/6586/a5b14994c80cdfa5a49...
# 437510        3  train_val2018/Plantae/7444/bbfb68b25f5debd876b...
# 437511        3  train_val2018/Aves/3555/68e5cabe14b6d767b25824...
# 437512        3  train_val2018/Plantae/7245/df6b20139f4a14e31e9...
# 437513        6  train_val2018/Plantae/7767/be2255e9252f7a1a260...
#
#                    rights_holder  height  width
# id
# 1             Jonathan Carpenter     600    800
# 2                  Marion Zöller     600    800
# 3                      phylocode     640    800
# 4                   J. N. Stuart     533    800
# 5       Alfonso Gutiérrez Aldana     533    800
# ...                          ...     ...    ...
# 437509            Kathleen Sayce     800    600
# 437510            Sam Kieschnick     800    600
# 437511            Luis Guillermo     452    800
# 437512                 kylejones     800    597
# 437513            Justin Johnsen     800    600
#
# [437513 rows x 5 columns]
#         image_id  category_id
# id
# 1              1         7477
# 2              2         2820
# 3              3         2757
# 4              4         4219
# 5              5         3942
# ...          ...          ...
# 437509    437509         6586
# 437510    437510         7444
# 437511    437511         3555
# 437512    437512         7245
# 437513    437513         7767
#
# [437513 rows x 2 columns]
#        kingdom                             name           family  \
# 0     Animalia            Hermodice carunculata     Amphinomidae
# 1     Animalia        Phragmatopoma californica    Sabellariidae
# 2     Animalia            Eudistylia vancouveri       Sabellidae
# 3     Animalia               Galeolaria hystrix       Serpulidae
# 4     Animalia               Serpula columbiana       Serpulidae
# ...        ...                              ...              ...
# 8137   Plantae  Neogastroclonium subarticulatum      Champiaceae
# 8138  Protozoa              Lycogala epidendrum     Tubiferaceae
# 8139  Protozoa                   Fuligo septica      Physaraceae
# 8140  Protozoa               Leocarpus fragilis      Physaraceae
# 8141  Protozoa                 Brefeldia maxima  Stemonitidaceae
#
#      supercategory      phylum    id          order             genus  \
# 0         Animalia    Annelida     0   Phyllodocida         Hermodice
# 1         Animalia    Annelida     1      Sabellida     Phragmatopoma
# 2         Animalia    Annelida     2      Sabellida        Eudistylia
# 3         Animalia    Annelida     3      Sabellida        Galeolaria
# 4         Animalia    Annelida     4      Sabellida           Serpula
# ...            ...         ...   ...            ...               ...
# 8137       Plantae  Rhodophyta  8137  Rhodymeniales  Neogastroclonium
# 8138      Protozoa   Mycetozoa  8138       Liceales          Lycogala
# 8139      Protozoa   Mycetozoa  8139     Physarales            Fuligo
# 8140      Protozoa   Mycetozoa  8140     Physarales         Leocarpus
# 8141      Protozoa   Mycetozoa  8141   Stemonitales         Brefeldia
#
#                 class
# 0          Polychaeta
# 1          Polychaeta
# 2          Polychaeta
# 3          Polychaeta
# 4          Polychaeta
# ...               ...
# 8137  Florideophyceae
# 8138      Myxomycetes
# 8139      Myxomycetes
# 8140      Myxomycetes
# 8141      Myxomycetes
#
# [8142 rows x 9 columns]

# %%
val = join_dataframes(vimages2018, vanno2018, cats, vloc)
val['set'] = "validation"

train = join_dataframes(timages2018, tanno2018, cats, tloc)
train['set'] = 'train'
df = pd.concat([train, val]).reset_index(drop=True)

df['name'] = df['name'].apply(lambda x: '_'.join(x.split(' ')))
df['new_dirs'] = df.apply(lambda x: f"Fungi_{x['phylum']}_{x['class']}_{x['order']}_{x['family']}_{x['name']}", axis=1)
df['new_paths'] = df['new_dirs'] + '/' + df['file_name'].str.split('/').str[-1]

# target = data / '2018' / 'train_val'
# target.mkdir(exist_ok=True)
# for group in df.groupby('new_dirs'):
#     target_dir = target / group[0]
#     target_dir.mkdir(exist_ok=True)
#     for file in group[1]['file_name']:
#         file = data / '2018' / Path(file)
#         parent_dir = file.parent
#         file.rename(target_dir / group[1]['new_paths'])
#     parent_dir.rmdir()

df.loc[:, 'file_name'] = df['file_name'].str.split('/').str[-1]
df = df.drop(['category_id', 'new_paths'], axis=1)
df['specific_epithet'] = df['name'].str.split(' ').str[-1]
df['image_dir_name'] = "Fungi_" + df['phylum'] + '_' + df['class'] + '_' + df['order'] + '_' + df['family'] + '_' + df['genus'] + '_' + df['specific_epithet']
df = df.rename(columns={'lon': 'longitude', 'lat': 'latitude', 'loc_uncert': 'location_uncertainty'})
# df.to_csv(data / '2018' / 'train_val.csv', index=False)

# %%
# This is just fixing a screwed up made when joining the 2018 and 2021 datasets..
all = Path.cwd().parent / 'data' / 'train'
for f in all.iterdir():
    if f.is_file():
        genus = df[df['file_name'] == f.name]['new_dirs'].values
        if len(genus) > 0:
            genus = genus[0]
            if not (all / genus).exists():
                (all / genus).mkdir(exist_ok=True)
            f.rename(all / genus / f.name)
        else:
            print(f.name)

# %% [markdown]
# ## 2021 Dataset

# %%
display(timages2021)
display(tanno2021)
display(tcat2021)
# Out:
#          width  height                                          file_name  \
# id
# 0          500     500  train/02912_Animalia_Chordata_Actinopterygii_S...
# 1          500     333  train/04831_Animalia_Chordata_Mammalia_Rodenti...
# 2          500     375  train/05015_Animalia_Chordata_Reptilia_Squamat...
# 3          500     375  train/05163_Animalia_Chordata_Reptilia_Testudi...
# 4          500     375  train/04983_Animalia_Chordata_Reptilia_Squamat...
# ...        ...     ...                                                ...
# 2686838    500     281  train/08843_Plantae_Tracheophyta_Magnoliopsida...
# 2686839    500     335  train/04661_Animalia_Chordata_Mammalia_Artioda...
# 2686840    500     354  train/02617_Animalia_Arthropoda_Insecta_Orthop...
# 2686841    500     335  train/04438_Animalia_Chordata_Aves_Piciformes_...
# 2686842    500     375  train/04540_Animalia_Chordata_Aves_Strigiforme...
#
#          license            rights_holder                       date  \
# id
# 0              0            Ken-ichi Ueda  2010-07-14 20:19:00+00:00
# 1              0          Michelle S. Koo  2010-07-06 22:17:00+00:00
# 2              1    105615097470186309865  2009-05-04 00:00:00+00:00
# 3              1                   biosam  2009-05-04 00:00:00+00:00
# 4              1                   biosam  2009-05-05 00:00:00+00:00
# ...          ...                      ...                        ...
# 2686838        1  Marilyn falcón Llacctas  2017-01-07 23:08:00+00:00
# 2686839        1            Glenn Caspers  2018-09-23 14:47:00+00:00
# 2686840        1             Greg Holland  2011-09-05 07:20:00+00:00
# 2686841        1            Glenn Caspers  2018-09-16 13:26:00+00:00
# 2686842        1                mferguson  2019-03-06 14:56:00+00:00
#
#          latitude  longitude  location_uncertainty
# id
# 0        43.83486  -71.22231                  77.0
# 1        38.86995 -120.19326                   NaN
# 2        35.14218 -116.10415                   NaN
# 3        35.09829 -116.02979               28734.0
# 4        35.01099 -115.47336                   NaN
# ...           ...        ...                   ...
# 2686838 -12.16751  -76.92011                6578.0
# 2686839  37.70054 -123.01332                2649.0
# 2686840  40.04478 -105.18851                 244.0
# 2686841  37.86510 -119.53833                9798.0
# 2686842  43.85086  -79.02037                8923.0
#
# [2686843 rows x 9 columns]
#          image_id  category_id
# id
# 0               0         2912
# 1               1         4831
# 2               2         5015
# 3               3         5163
# 4               4         4983
# ...           ...          ...
# 2686838   2686838         8843
# 2686839   2686839         4661
# 2686840   2686840         2617
# 2686841   2686841         4438
# 2686842   2686842         4540
#
# [2686843 rows x 2 columns]
#                            name             common_name supercategory  \
# id
# 0          Lumbricus terrestris        Common Earthworm      Animalia
# 1          Sabella spallanzanii   Mediterranean Fanworm      Animalia
# 2            Serpula columbiana      Serpula columbiana      Animalia
# 3     Spirobranchus cariniferus          Blue Tube Worm      Animalia
# 4            Eratigena duellica      Giant House Spider     Arachnids
# ...                         ...                     ...           ...
# 9995             Psilotum nudum      skeleton fork fern        Plants
# 9996       Tmesipteris elongata    Tmesipteris elongata        Plants
# 9997        Azolla filiculoides              water fern        Plants
# 9998            Salvinia minima          water spangles        Plants
# 9999         Lygodium japonicum  Japanese climbing fern        Plants
#
#        kingdom        phylum           class        order        family  \
# id
# 0     Animalia      Annelida      Clitellata  Haplotaxida   Lumbricidae
# 1     Animalia      Annelida      Polychaeta    Sabellida    Sabellidae
# 2     Animalia      Annelida      Polychaeta    Sabellida    Serpulidae
# 3     Animalia      Annelida      Polychaeta    Sabellida    Serpulidae
# 4     Animalia    Arthropoda       Arachnida      Araneae    Agelenidae
# ...        ...           ...             ...          ...           ...
# 9995   Plantae  Tracheophyta  Polypodiopsida   Psilotales   Psilotaceae
# 9996   Plantae  Tracheophyta  Polypodiopsida   Psilotales   Psilotaceae
# 9997   Plantae  Tracheophyta  Polypodiopsida  Salviniales  Salviniaceae
# 9998   Plantae  Tracheophyta  Polypodiopsida  Salviniales  Salviniaceae
# 9999   Plantae  Tracheophyta  Polypodiopsida  Schizaeales   Lygodiaceae
#
#               genus specific_epithet  \
# id
# 0         Lumbricus       terrestris
# 1           Sabella     spallanzanii
# 2           Serpula       columbiana
# 3     Spirobranchus      cariniferus
# 4         Eratigena         duellica
# ...             ...              ...
# 9995       Psilotum            nudum
# 9996    Tmesipteris         elongata
# 9997         Azolla     filiculoides
# 9998       Salvinia           minima
# 9999       Lygodium        japonicum
#
#                                          image_dir_name
# id
# 0     00000_Animalia_Annelida_Clitellata_Haplotaxida...
# 1     00001_Animalia_Annelida_Polychaeta_Sabellida_S...
# 2     00002_Animalia_Annelida_Polychaeta_Sabellida_S...
# 3     00003_Animalia_Annelida_Polychaeta_Sabellida_S...
# 4     00004_Animalia_Arthropoda_Arachnida_Araneae_Ag...
# ...                                                 ...
# 9995  09995_Plantae_Tracheophyta_Polypodiopsida_Psil...
# 9996  09996_Plantae_Tracheophyta_Polypodiopsida_Psil...
# 9997  09997_Plantae_Tracheophyta_Polypodiopsida_Salv...
# 9998  09998_Plantae_Tracheophyta_Polypodiopsida_Salv...
# 9999  09999_Plantae_Tracheophyta_Polypodiopsida_Schi...
#
# [10000 rows x 11 columns]

# %%
train2 = join_dataframes(timages2021, tanno2021, tcat2021)
val2 = join_dataframes(vimages2021, vanno2021, vcat2021)
train2['set'] = 'train'
val2['set'] = 'validation'
df2 = pd.concat([train2, val2]).reset_index(drop=True)

# %%
tpath = data / '2021' / 'train'
for p in tpath.iterdir():
    new_name = '_'.join(p.name.split('_')[1:])
    new_dir = tpath / new_name
    new_dir.mkdir()
    for f in p.iterdir():
        f.rename(new_dir / f.name)
    p.rmdir()

# %%
df2['image_dir_name'] = df2['image_dir_name'].apply(lambda x: '_'.join(x.split('_')[1:]))
df2 = df2.drop('category_id', axis=1)
df2['dataset'] = '2021'
df2['file_name'] = df2['file_name'].str.split('/').str[-1]

# %%
df = pd.concat([df, df2], ignore_index=True)
df['file_path'] = 'Mushroom-Classifier/data/train/' + df['image_dir_name'] + '/' + df['file_name']
df['gcs_path'] = 'gs://mush-img-repo/train/ ' + df['image_dir_name'] + '/' + df['file_name']
df['class_id'] = df.groupby('name').ngroup()
df.to_csv(root / 'data' / 'train_val.csv', index=False)
