# %%
import regex as re
import pandas as pd
import numpy as np
from src.data_processing import preprocessing

# %%
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-`lsb_release -c -s` main" | sudo tee /etc/apt/sources.list.d/gcsfuse.list
# !curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
# !sudo apt-get -y -q update
# !sudo apt-get -y -q install gcsfuse
from google.colab import auth
auth.authenticate_user()
# !mkdir -p gcp
bucket_name='inatdatabase'
# !gcsfuse --implicit-dirs --limit-bytes-per-sec -1 --limit-ops-per-sec -1 {bucket_name} gcp
# Out:
# deb http://packages.cloud.google.com/apt gcsfuse-bionic main

# %%
preprocessing.rename_images('/content/gcp/gyro_inat/', 'gyroromitra')
preprocessing.rename_images('/content/gcp/morels_inat/', 'morchella')
preprocessing.rename_images('/content/gcp_bucket/gyro/inat/', 'gyromitra')
preprocessing.rename_images('/content/gcp_bucket/morels/inat/', 'morchella')
preprocessing.rename_images('/content/gcp_bucket/gyro/MO/', 'gyromitra')
preprocessing.rename_images('/content/gcp_bucket/morels/MO/', 'morchella')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2881                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2882                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2883             finally:
#
# <ipython-input-24-481ec423bb22> in <module>()
#       3 rename_images('/content/gcp/gyro_inat/', 'gyroromitra')
# ----> 4 rename_images('/content/gcp/morels_inat/', 'morchella')
#       5 rename_images('/content/gcp_bucket/ascos/', 'ascomycota')
#
# <ipython-input-20-c86f123d0dd8> in rename_images(fpath, label)
#       5         new_name = label + fname
# ----> 6         os.rename(os.path.join(fpath, fname), os.path.join(fpath, new_name))
#
# ...

# %%
morels = preprocessing.return_labeled_df(filepath='/content/gcp/morels/inat', cloud_path='g://auto_ml_muchrooms/morels/inat/', label='Morels')
gyro = preprocessing.return_labeled_df(filepath='/content/gcp/gyro/inat', cloud_path='g://auto_ml_muchrooms/gyro/inat/', label='Gyromitra')
